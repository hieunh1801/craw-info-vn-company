# %% [markdown]
# ## Lấy về các thành phố

# %%
# url
import requests
url_city = "https://thongtindoanhnghiep.co/api/city"
response = requests.get(url_city)
response.encoding = 'utf-8'
# print(response.text)
content = response.json()
# print(content["LtsItem"])

# %%
list_city = [{'Type': 1, 'SolrID': '/tien-giang', 'ID': 1, 'Title': 'Tiền Giang', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 10592}, {'Type': 1, 'SolrID': '/hung-yen', 'ID': 2, 'Title': 'Hưng Yên', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 11835}, {'Type': 1, 'SolrID': '/ha-noi', 'ID': 3, 'Title': 'Hà Nội', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 274855}, {'Type': 1, 'SolrID': '/tp-ho-chi-minh', 'ID': 4, 'Title': 'TP Hồ Chí Minh', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 455281}, {'Type': 1, 'SolrID': '/ca-mau', 'ID': 5, 'Title': 'Cà Mau', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 10648}, {'Type': 1, 'SolrID': '/dac-lac', 'ID': 6, 'Title': 'Đắc Lắc', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 11160}, {'Type': 1, 'SolrID': '/nam-dinh', 'ID': 7, 'Title': 'Nam Định', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 11803}, {'Type': 1, 'SolrID': '/quang-ninh', 'ID': 8, 'Title': 'Quảng Ninh', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 19265}, {'Type': 1, 'SolrID': '/dak-nong', 'ID': 9, 'Title': 'Đắk Nông', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 5235}, {'Type': 1, 'SolrID': '/da-nang', 'ID': 10, 'Title': 'Đà Nẵng', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 39778}, {'Type': 1, 'SolrID': '/hai-duong', 'ID': 11, 'Title': 'Hải Dương', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 16413}, {'Type': 1, 'SolrID': '/long-an', 'ID': 12, 'Title': 'Long An', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 18688}, {'Type': 1, 'SolrID': '/ben-tre', 'ID': 13, 'Title': 'Bến Tre', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 8161}, {'Type': 1, 'SolrID': '/dong-thap', 'ID': 14, 'Title': 'Đồng Tháp', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 10364}, {'Type': 1, 'SolrID': '/vinh-long', 'ID': 15, 'Title': 'Vĩnh Long', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 7159}, {'Type': 1, 'SolrID': '/kien-giang', 'ID': 16, 'Title': 'Kiên Giang', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 16990}, {'Type': 1, 'SolrID': '/tra-vinh', 'ID': 17, 'Title': 'Trà Vinh', 'STT':
': None, 'Updated': None, 'TotalDoanhNghiep': 9377}, {'Type': 1, 'SolrID': '/bac-giang', 'ID': 54, 'Title': 'Bắc Giang', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 11408}, {'Type': 1, 'SolrID': '/ha-tinh', 'ID': 55, 'Title': 'Hà Tĩnh', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 10549}, {'Type': 1, 'SolrID': '/ninh-binh', 'ID': 56, 'Title': 'Ninh Bình', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 7829}, {'Type': 1, 'SolrID': '/binh-thuan', 'ID': 57, 'Title': 'Bình Thuận', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 11128}, {'Type': 1, 'SolrID': '/kon-tum', 'ID': 58, 'Title': 'Kon Tum', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 4654}, {'Type': 1, 'SolrID': '/vinh-phuc', 'ID': 59, 'Title': 'Vĩnh Phúc', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 12638}, {'Type': 1, 'SolrID': '/bac-lieu', 'ID': 60, 'Title': 'Bạc Liêu', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 5376}, {'Type': 1, 'SolrID': '/yen-bai', 'ID': 61, 'Title': 'Yên Bái', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 4815}, {'Type': 1, 'SolrID': '/dien-bien', 'ID': 62, 'Title': 'Điện Biên', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 3150}, {'Type': 1, 'SolrID': '/ha-giang', 'ID': 63, 'Title': 'Hà Giang', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 4545}, {'Type': 1, 'SolrID': '/chua-ro', 'ID': 64, 'Title': 'Chưa rõ', 'STT': 0, 'Created': None, 'Updated': None, 'TotalDoanhNghiep': 61817}]
list_city_name = []
for city in list_city:
    list_city_name.append({'name': city['Title'], 'solrId': city['SolrID']})

# print(list_city_name)

# %%
# list tên các tỉnh thành
list_city_name = [{'name': 'Tiền Giang', 'solrId': '/tien-giang'}, {'name': 'Hưng Yên', 'solrId': '/hung-yen'}, {'name': 'Hà Nội', 'solrId': '/ha-noi'}, {'name': 'TP Hồ Chí Minh', 'solrId': '/tp-ho-chi-minh'}, {'name': 'Cà Mau', 'solrId': '/ca-mau'}, {'name': 'Đắc Lắc', 'solrId': '/dac-lac'}, {'name': 'Nam Định', 'solrId': '/nam-dinh'}, {'name': 'Quảng Ninh', 'solrId': '/quang-ninh'}, {'name': 'Đắk Nông', 'solrId': '/dak-nong'}, {'name': 'Đà Nẵng', 'solrId': '/da-nang'}, {'name': 'Hải Dương', 'solrId': '/hai-duong'}, {'name': 'Long An', 'solrId': '/long-an'}, {'name': 'Bến Tre', 'solrId': '/ben-tre'}, {'name': 'Đồng Tháp', 'solrId': '/dong-thap'}, {'name': 'Vĩnh Long', 'solrId': '/vinh-long'}, {'name': 'Kiên Giang', 'solrId': '/kien-giang'}, {'name': 'Trà Vinh', 'solrId': '/tra-vinh'}, {'name': 'Sóc Trăng', 'solrId': '/soc-trang'}, {'name': 'Bắc Ninh', 'solrId': '/bac-ninh'}, {'name': 'Thanh Hoá', 'solrId': '/thanh-hoa'}, {'name': 'Vũng Tàu', 'solrId': '/vung-tau'}, {'name': 'Đồng Nai', 'solrId': '/dong-nai'}, {'name': 'Bình Dương', 'solrId': '/binh-duong'}, {'name': 'Thái Nguyên', 'solrId': '/thai-nguyen'}, {'name': 'Thái Bình', 'solrId': '/thai-binh'}, {'name': 'Cần Thơ', 'solrId': '/can-tho'}, {'name': 'Nghệ An', 'solrId': '/nghe-an'}, {'name': 'Huế', 'solrId': '/hue'}, {'name': 'Bình Phước', 'solrId': '/binh-phuoc'}, {'name': 'Quảng Nam', 'solrId': '/quang-nam'}, {'name': 'Quảng Ngãi', 'solrId': '/quang-ngai'}, {'name': 'Ninh Thuận', 'solrId': '/ninh-thuan'}, {'name': 'Lào Cai', 'solrId': '/lao-cai'}, {'name': 'Hải Phòng', 'solrId': '/hai-phong'}, {'name': 'An Giang', 'solrId': '/an-giang'}, {'name': 'Phú Thọ', 'solrId': '/phu-tho'}, {'name': 'Tây Ninh', 'solrId': '/tay-ninh'}, {'name': 'Khánh Hòa', 'solrId': '/khanh-hoa'}, {'name': 'Phú Yên', 'solrId': '/phu-yen'}, {'name': 'Hòa Bình', 'solrId': '/hoa-binh'}, {'name': 'Tuyên Quang', 'solrId': '/tuyen-quang'}, {'name': 'Lai Châu', 'solrId': '/lai-chau'}, {'name': 'Hậu Giang', 'solrId': '/hau-giang'}, {'name': 'Lâm Đồng', 'solrId': '/lam-dong'}, {'name': 'Lạng Sơn', 'solrId': '/lang-son'}, {'name': 'Hà Nam', 'solrId': '/ha-nam'}, {'name': 'Bắc Cạn', 'solrId': '/bac-can'}, {'name': 'Bình Định', 'solrId': '/binh-dinh'}, {'name': 'Cao Bằng', 'solrId': '/cao-bang'}, {'name': 'Sơn La', 'solrId': '/son-la'}, {'name': 'Quảng Bình', 'solrId': '/quang-binh'}, {'name': 'Quảng Trị', 'solrId': '/quang-tri'}, {'name': 'Gia Lai', 'solrId': '/gia-lai'}, {'name': 'Bắc Giang', 'solrId': '/bac-giang'}, {'name': 'Hà Tĩnh', 'solrId': '/ha-tinh'}, {'name': 'Ninh Bình', 'solrId': '/ninh-binh'}, {'name': 'Bình Thuận', 'solrId': '/binh-thuan'}, {'name': 'Kon Tum', 'solrId': '/kon-tum'}, {'name': 'Vĩnh Phúc', 'solrId': '/vinh-phuc'}, {'name': 'Bạc Liêu', 'solrId': '/bac-lieu'}, {'name': 'Yên Bái', 'solrId': '/yen-bai'}, {'name': 'Điện Biên', 'solrId': '/dien-bien'}, {'name': 'Hà Giang', 'solrId': '/ha-giang'}, {'name': 'Chưa rõ', 'solrId': '/chua-ro'}]
# list_city_name

# %% [markdown]
# ## Lấy về các mã số thuế của doanh nghiệp trong 1 thành phố

# %%
# Example for one Page
import requests
from connection_to_db import execute_count_query
url = "https://thongtindoanhnghiep.co/api/company?l=ha-noi&&r=100&&p=1"
response = requests.get(url)
response.encoding = 'utf-8'
content = response.json()
list_data_sort_company = content["LtsItems"]
total_in_one_city = int(content["Option"]["TotalRow"])
print(total_in_one_city)
for company in list_data_sort_company:
    query = f"""
    INSERT INTO public.company_short(company_tax_number, company_name)
    VALUES ('{company["MaSoThue"]}', '{company['Title']}') 
    ON CONFLICT (company_tax_number) DO NOTHING;"""
    execute_count_query(query)
# Out:
# 274862

# %%
# Example for multiple page in one city
import requests
from connection_to_db import execute_count_query

def generate_data_for_one_city(city_name="ha_noi"):
    page = 1
    while True:
        url = f"https://thongtindoanhnghiep.co/api/company?l={city_name}&&r=100&&p={page}"
        response = requests.get(url)
        response.encoding = 'utf-8'
        content = response.json()
        list_data_sort_company = content["LtsItems"]
        total_in_one_city = int(content["Option"]["TotalRow"]) # tổng số doanh nghiệp trong 1 thành phố
        if page * 100 > total_in_one_city:
            print(page * 100, ' ', total_in_one_city)
            break
        for company in list_data_sort_company:
            query = f"""
            INSERT INTO public.company_short(company_tax_number, company_name)
            VALUES ('{company["MaSoThue"]}', $$escape '{company['Title']}'$$) 
            ON CONFLICT (company_tax_number) DO NOTHING;"""
            execute_count_query(query)
        page = page + 1
        print(page)
generate_data_for_one_city(city_name="ha-noi")

# %%
# true -> True
# false -> False
# null -> None
company = {
  "Type": 11,
  "SolrID": "/3901212654-cong-ty-tnhh-mtv-ngo-trong-phat",
  "ID": 1192190,
  "MaSoThue": "3901212654",
  "NgayCap": "2015-11-20T00:00:00Z",
  "NgayDongMST": None,
  "Title": "Công Ty TNHH Mtv Ngô Trọng Phát",
  "TitleEn": "NGO TRONG PHAT CO., LTD",
  "TitleEnAscii": None,
  "DiaChiCongTy": "Tổ 17, ấp Tân Tiến - Xã Tân Lập - Huyện Tân Biên - Tây Ninh",
  "DiaChiNhanThongBaoThue": "Tổ 17, ấp Tân Tiến - Xã Tân Lập - Huyện Tân Biên - Tây Ninh",
  "NamTaiChinh": "2015-01-01T00:00:00Z",
  "MaSoHienThoi": "",
  "NgayNhanToKhai": "2015-11-17T00:00:00Z",
  "NgayBatDauHopDong": "2015-11-20T00:00:00Z",
  "VonDieuLe": "",
  "TongSoLaoDong": 5,
  "CapChuongLoaiKhoan": "3-754-190-194",
  "HinhThucThanhToan": "",
  "PhuongPhapTinhThueGTGT": "Trực tiếp doanh thu",
  "ChuSoHuu": "Ngô Công Tấn",
  "ChuSoHuu_DiaChi": "Tổ 5, ấp Hội Thanh-Xã Tân Hội-Huyện Tân Châu-Tây Ninh",
  "GiamDoc": "",
  "GiamDoc_DiaChi": "",
  "KeToanTruong": "Ngô Công Tấn",
  "KeToanTruong_DiaChi": "",
  "Created": "2015-11-23T23:20:34Z",
  "Updated": "2015-11-23T23:20:34Z",
  "IsDelete": False,
  "RequestChanged": False,
  "ExitsInGDT": True,
  "SourceID": 1336327,
  "TinhThanhID": 37,
  "TinhThanhTitle": "Tây Ninh",
  "TinhThanhTitleAscii": "/tay-ninh",
  "QuanHuyenID": 194,
  "QuanHuyenTitle": "Huyện Tân Biên",
  "QuanHuyenTitleAscii": "/tay-ninh/huyen-tan-bien",
  "PhuongXaID": 1402,
  "PhuongXaTitle": "Xã Tân Lập",
  "PhuongXaTitleAscii": "/tay-ninh/huyen-tan-bien/xa-tan-lap",
  "NoiDangKyQuanLyID": 5372,
  "NoiDangKyQuanLy_CoQuanTitle": "Chi cục Thuế Huyện Tân Biên",
  "NoiDangKyQuanLy_CoQuanTitleAscii": "/co-quan-quan-ly/chi-cuc-thue-huyen-tan-bien",
  "NoiDangKyQuanLy_DienThoai": "0977366216",
  "NoiDangKyQuanLy_Fax": None,
  "NoiNopThueID": None,
  "NoiNopThue_DienThoai": "0977366216",
  "NoiNopThue_Fax": None,
  "NoiNopThue_CoQuanTitle": "",
  "NoiNopThue_CoQuanTitleAscii": "",
  "QuyetDinhThanhLap": None,
  "QuyetDinhThanhLap_NgayCap": None,
  "QuyetDinhThanhLap_CoQuanCapID": None,
  "QuyetDinhThanhLap_CoQuanCapTitle": "",
  "QuyetDinhThanhLap_CoQuanCapTitleAscii": "",
  "GiayPhepKinhDoanh_CoQuanCapID": 95,
  "GiayPhepKinhDoanh_CoQuanCapTitle": "Tỉnh Tây Ninh",
  "GiayPhepKinhDoanh_CoQuanCapTitleAscii": "/co-quan-quan-ly/tinh-tay-ninh",
  "GiayPhepKinhDoanh": "3901212654",
  "GiayPhepKinhDoanh_NgayCap": "2015-11-20T00:00:00Z",
  "LoaiHinhID": None,
  "LoaiHinhTitle": "",
  "LoaiHinhTitleAscii": "",
  "NganhNgheID": 414,
  "NganhNgheTitle": "Bán buôn nông, lâm sản nguyên liệu (trừ gỗ, tre, nứa) và động vật sống",
  "NganhNgheTitleAscii": "/nganh-nghe/ban-buon-nong-lam-san-nguyen-lieu-tru-go-tre-nua-va-dong-vat-song",
  "DSNganhNgheKinhDoanh": [],
  "DSNganhNgheKinhDoanhID": [
    50,
    414,
    490,
    590
  ],
  "DSMaNganhNgheKinhDoanh": [
    "A",
    "G",
    "H",
    "01",
    "46",
    "49",
    "016",
    "454",
    "466",
    "493",
    "0146",
    "4620",
    "4669",
    "4933",
    "01630",
    "46900"
  ],
  "Lv1": None,
  "Lv2": None,
  "Lv3": None,
  "Lv4": None,
  "Lv5": None,
  "DSNganHang": [],
  "DSNganHangID": [],
  "DSThuePhaiNop": [
    "1|/thue/gia-tri-gia-tang|Giá trị gia tăng",
    "2|/thue/thu-nhap-doanh-nghiep|Thu nhập doanh nghiệp",
    "4|/thue/mon-bai|Môn bài",
    "9|/thue/xuat-nhap-khau|Xuất nhập khẩu"
  ],
  "DSThuePhaiNopID": [
    1,
    2,
    4,
    9
  ],
  "LtsDoanhNghiepTrucThuoc": [],
  "DSTags": [
    "3901212654",
    "0977366216",
    "NGO TRONG PHAT CO., LTD",
    "Tây Ninh",
    "Huyện Tân Biên",
    "Xã Tân Lập",
    "Ngô Công Tấn"
  ]
}

# %% [markdown]
# - url: https://thongtindoanhnghiep.co/api/company/3901212654
# - company_name: tên công ty
# - registered_address: địa chỉ đăng ký
# - company_address: địa chỉ công ty
# - owner_name: tên người sở hữu
# - occupation: ngành nghề kinh doanh
# - tax_number: mã số thuết
#
# - city: tỉnh, thành phố
# - district: huyện
# - ward: xã
#
# - surname: họ
# - middlename: tên đệm
# - lastname: tên

# %%
import requests
url = "https://thongtindoanhnghiep.co/api/company/3901212654"
response = requests.get(url)
company = response.json()

# surname: họ
# middlename: tên đệm
# lastname: tên
full_name = "Nguyeenx"
def split_name(full_name):
    if full_name == '':
        return ('', '', '')
    full_name_array = full_name.split(" ")
    lastname = full_name_array.pop(-1) 
    surname = full_name_array.pop(0) if len(full_name_array) != 0 else ""
    middlename = " ".join(full_name_array)
    return (surname, middlename, lastname)

print(split_name(full_name))
# Out:
# ('', '', 'Nguyeenx')

# %%
def insert_to_company(company):
    company_name = company["Title"]
    registered_address = company["NoiDangKyQuanLy_CoQuanTitle"]
    company_address = company["DiaChiCongTy"]
    owner_name = company["ChuSoHuu"]
    occupation = company["NganhNgheTitle"]
    tax_number = company["MaSoThue"]
    city = company["TinhThanhTitle"]
    district = company["QuanHuyenTitle"]
    ward = company["PhuongXaTitle"]
    full_name = company["ChuSoHuu"]
    surname, middlename, lastname = split_name(full_name)
    url = f"""https://thongtindoanhnghiep.co/api/company/{tax_number}"""
    query = f"""
    INSERT INTO public.company_info(
            company_name, url, registered_address, company_address, owner_name, occupation, tax_number, city, district, ward, full_name, surname, middlename, lastname)
    VALUES ( 
    $$escape '{company_name}'$$,
    $$escape '{url}'$$,
    $$escape '{registered_address}'$$, 
    $$escape '{company_address}'$$,
    $$escape '{owner_name}'$$,
    $$escape '{occupation}'$$,
    $$escape '{tax_number}'$$,
    $$escape '{city}'$$,
    $$escape '{district}'$$,
    $$escape '{ward}'$$,
    $$escape '{full_name}'$$,
    $$escape '{surname}'$$,
    $$escape '{middlename}'$$,
    $$escape '{lastname}'$$) ON CONFLICT (tax_number) DO NOTHING;
    """
    print(query)

insert_to_company(company=company)
# Out:
#     INSERT INTO public.company_info(
#             company_name, url, registered_address, company_address, owner_name, occupation, tax_number, city, district, ward, full_name, surname, middlename, lastname)
#     VALUES (
#     $$escape 'Công Ty TNHH Mtv Ngô Trọng Phát'$$,
#     $$escape 'https://thongtindoanhnghiep.co/api/company/3901212654'$$,
#     $$escape 'Chi cục Thuế Huyện Tân Biên'$$,
#     $$escape 'Tổ 17, ấp Tân Tiến - Xã Tân Lập - Huyện Tân Biên - Tây Ninh'$$,
#     $$escape 'Ngô Công Tấn'$$,
#     $$escape 'Bán buôn nông, lâm sản nguyên liệu (trừ gỗ, tre, nứa) và động vật sống'$$,
#     $$escape '3901212654'$$,
#     $$escape 'Tây Ninh'$$,
#     $$escape 'Huyện Tân Biên'$$,
#     $$escape 'Xã Tân Lập'$$,
#     $$escape 'Ngô Công Tấn'$$,
#     $$escape 'Ngô'$$,
#     $$escape 'Công'$$,
#     $$escape 'Tấn'$$) ON CONFLICT (tax_number) DO NOTHING;

# %%
# Example for multiple page in one city
import requests
from connection_to_db import execute_count_query


def split_name(full_name):
    """
        Tách tên: "Nguyễn Hữu Hiếu A"
        RETURN:
            - "Nguyễn Hữu Hiếu" -> ('Nguyeenx', 'Hữu', 'Hiếu')
            - "Nguyeenx Hữu"    -> ('Nguyeenx', '', 'Hữu')
            - "Nguyeenx"        -> ('', '', 'Nguyeenx')

    """
    if full_name is '':
        return ('', '', '')
    full_name_array = full_name.split(" ")
    lastname = full_name_array.pop(-1)
    surname = full_name_array.pop(0) if len(full_name_array) != 0 else ""
    middlename = " ".join(full_name_array)
    return (surname, middlename, lastname)


def generate_data_for_one_city(city_name="ha_noi"):
    page = 1
    while True:
        url = f"https://thongtindoanhnghiep.co/api/company?l={city_name}&&r=100&&p={page}"
        response = requests.get(url)
        response.encoding = 'utf-8'
        content = response.json()
        list_data_sort_company = content["LtsItems"]
        # tổng số doanh nghiệp trong 1 thành phố
        total_in_one_city = int(content["Option"]["TotalRow"])
        if page * 100 > total_in_one_city:
            print(page * 100, ' ', total_in_one_city)
            break
        for company in list_data_sort_company:
            url_company_detail = {company["MaSoThue"]}
            res = requests.get(url)
            insert_to_company(company=res.json())

        page = page + 1
        print(page)


def insert_to_company(company):
    print(company)
    company_name = company["Title"]
    registered_address = company["NoiDangKyQuanLy_CoQuanTitle"] if company["NoiDangKyQuanLy_CoQuanTitle"] else ''
    company_address = company["DiaChiCongTy"]
    owner_name = company["ChuSoHuu"]
    occupation = company["NganhNgheTitle"]
    tax_number = company["MaSoThue"]
    city = company["TinhThanhTitle"]
    district = company["QuanHuyenTitle"]
    ward = company["PhuongXaTitle"]
    full_name = company["ChuSoHuu"]
    surname, middlename, lastname = split_name(full_name)
    url = f"""https://thongtindoanhnghiep.co/api/company/{tax_number}"""
    query = f"""
    INSERT INTO public.company_info(
            company_name, url, registered_address, company_address, owner_name, occupation, tax_number, city, district, ward, full_name, surname, middlename, lastname)
    VALUES ( 
    $$escape '{company_name}'$$,
    $$escape '{url}'$$,
    $$escape '{registered_address}'$$, 
    $$escape '{company_address}'$$,
    $$escape '{owner_name}'$$,
    $$escape '{occupation}'$$,
    $$escape '{tax_number}'$$,
    $$escape '{city}'$$,
    $$escape '{district}'$$,
    $$escape '{ward}'$$,
    $$escape '{full_name}'$$,
    $$escape '{surname}'$$,
    $$escape '{middlename}'$$,
    $$escape '{lastname}'$$) ON CONFLICT (tax_number) DO NOTHING;
    """
    # print(query)


list_city_name = ['tien-giang', 'hung-yen', 'ha-noi', 'tp-ho-chi-minh', 'ca-mau', 'dac-lac', 'nam-dinh', 'quang-ninh', 'dak-nong', 'da-nang', 'hai-duong', 'long-an', 'ben-tre', 'dong-thap', 'vinh-long', 'kien-giang', 'tra-vinh', 'soc-trang', 'bac-ninh', 'thanh-hoa', 'vung-tau', 'dong-nai', 'binh-duong', 'thai-nguyen', 'thai-binh', 'can-tho', 'nghe-an', 'hue', 'binh-phuoc', 'quang-nam', 'quang-ngai',
                  'ninh-thuan', 'lao-cai', 'hai-phong', 'an-giang', 'phu-tho', 'tay-ninh', 'khanh-hoa', 'phu-yen', 'hoa-binh', 'tuyen-quang', 'lai-chau', 'hau-giang', 'lam-dong', 'lang-son', 'ha-nam', 'bac-can', 'binh-dinh', 'cao-bang', 'son-la', 'quang-binh', 'quang-tri', 'gia-lai', 'bac-giang', 'ha-tinh', 'ninh-binh', 'binh-thuan', 'kon-tum', 'vinh-phuc', 'bac-lieu', 'yen-bai', 'dien-bien', 'ha-giang', 'chua-ro']

for city in list_city_name:
    generate_data_for_one_city(city_name=city)
